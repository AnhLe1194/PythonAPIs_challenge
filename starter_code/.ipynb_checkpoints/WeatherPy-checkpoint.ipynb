# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %matplotlib notebook
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
print(weather_api_key)
# Out:
# 97a5f317ff8cdca54a2422c16a476313

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\programdata\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\programdata\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
for city in cities:
    print(city)
# Out:
# pacific grove
# hermanus
# hobyo
# pitimbu
# hobart
# upernavik
# bluff
# nizhneyansk
# hilo
# ituni
# sentyabrskiy
# bubaque
# ushuaia
# kapaa
# albany
# strezhevoy
# dolbeau
# hasaki
# saint george
# vao
# bac lieu
# toliary
# port blair
# vaini
# rikitea
# palabuhanratu
# mataura
# busselton
# los llanos de aridane
# hofn
# faanui
# tsihombe
# farmington
# petropavlovsk-kamchatskiy
# chuy
# new norfolk
# airai
# port hedland
# barentsburg
# raesfeld
# hope
# the pas
# seoul
# hami
# campbell river
# arraial do cabo
# illoqqortoormiut
# parnamirim
# kashiwazaki
# ouadda
# fukuma
# lasa
# jamestown
# wewak
# krupina
# tocopilla
# barrow
# atuona
# hare bay
# puerto suarez
# port elizabeth
# yellowknife
# punta arenas
# klaksvik
# praia
# tyler
# aswan
# porangatu
# san patricio
# tiksi
# tura
# severodvinsk
# olafsvik
# princeton
# puerto ayora
# daru
# beira
# leningradskiy
# dikson
# imbituba
# banda aceh
# acapulco
# imeni poliny osipenko
# mys shmidta
# cabo san lucas
# yenagoa
# praia da vitoria
# lagoa
# meybod
# bredasdorp
# jamame
# carnarvon
# satitoa
# hithadhoo
# okhotsk
# turayf
# paragominas
# ketchikan
# longyearbyen
# kaitangata
# saldanha
# sitka
# georgetown
# nanortalik
# zamora
# ponta do sol
# karratha
# biak
# guaratuba
# jeremoabo
# puerto colombia
# taolanaro
# muyezerskiy
# sao joao da barra
# bowen
# vardo
# ostersund
# hailey
# rocha
# manoel urbano
# cape town
# kayan
# butaritari
# qaanaaq
# touros
# yar-sale
# skjervoy
# port lincoln
# husavik
# haines junction
# gamba
# henderson
# bogotol
# xihua
# vaitupu
# honiara
# komsomolskiy
# gilazi
# plettenberg bay
# riohacha
# lompoc
# east london
# shimoda
# lagunas
# kishtwar
# yokadouma
# kahului
# cheyenne
# thompson
# tulagi
# aktau
# sao felix do xingu
# saint-philippe
# grand gaube
# atambua
# luderitz
# shingu
# sao sebastiao
# codrington
# mar del plata
# ribeira grande
# kamina
# tateyama
# limbang
# itarema
# nikolskoye
# maloy
# lewisporte
# longlac
# severo-kurilsk
# hervey bay
# atar
# muros
# nyurba
# zavoronezhskoye
# kavaratti
# vanino
# bababe
# zhigansk
# prescott
# ahipara
# port alfred
# barranca
# tessalit
# bandarbeyla
# champerico
# lokosovo
# kijini
# tasiilaq
# pevek
# houma
# lima
# ilulissat
# shetpe
# salalah
# high level
# constitucion
# khatanga
# tuktoyaktuk
# bam
# lebu
# grand river south east
# mahebourg
# nouadhibou
# avarua
# saint anthony
# hirara
# torbay
# port moresby
# amderma
# palmer
# sisimiut
# bethel
# bonavista
# kayasula
# ust-uda
# davila
# castro
# kungurtug
# kodiak
# bengkulu
# tarauaca
# kautokeino
# abnub
# rawson
# nome
# pontes e lacerda
# gat
# leh
# fairbanks
# kolaras
# totskoye
# canakkale
# fort nelson
# gewane
# shelburne
# pandan
# erenhot
# baruun-urt
# opuwo
# lucea
# puerto leguizamo
# jimma
# juba
# sedalia
# maceio
# finschhafen
# henties bay
# taoudenni
# chilca
# nizhniy kuranakh
# tahta
# broome
# shouguang
# cuiluan
# payo
# rantauprapat
# tumannyy
# sume
# nouakchott
# vagamo
# bolungarvik
# trelew
# coari
# masunga
# listvyanskiy
# colinas
# bembereke
# bay roberts
# waipawa
# kabale
# tiznit
# yugorsk
# ustye
# muncar
# brandon
# te anau
# boma
# dalneye konstantinovo
# goderich
# diego de almagro
# sakakah
# kon tum
# chara
# vallenar
# borogontsy
# vila franca do campo
# yangjiang
# ponta delgada
# acajutla
# warrnambool
# mezen
# fare
# kaspiyskiy
# gorom-gorom
# pagman
# russell
# sur
# ossora
# evensk
# ikole
# verkhnyaya sysert
# marovoay
# newport
# seabra
# abonnema
# icod de los vinos
# necochea
# smithers
# sechura
# ruteng
# zheleznodorozhnyy
# maniitsoq
# moiyabana
# alice springs
# coxim
# mrirt
# tazovskiy
# springfield
# yerbogachen
# santa maria
# tabory
# uwayl
# saleaula
# linhares
# tilichiki
# laguna
# umm bab
# parainen
# estremoz
# talnakh
# fernley
# vestmannaeyjar
# margate
# vila velha
# filingue
# souillac
# oistins
# calabozo
# xiuyan
# vredendal
# alyangula
# williams lake
# pozo colorado
# kirakira
# vuktyl
# los algarrobos
# louisbourg
# great yarmouth
# barawe
# kloulklubed
# tabou
# sao gabriel da cachoeira

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
units = "Imperial"
base_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}"

index = 0
set_count = 0

weather_city = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    try:
        city_url = f"{base_url}&q={city}"
        response = requests.get(city_url).json()
        print(f"Processing Record {index} of Set {set_count} | {city}")
        
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        weather_city.append(city)
        
    except:
        print("City not found. Skipping.. ")  
    
    index = index + 1
    
    if index == 50:
        index = 0
        set_count = set_count + 1
        
print("-----------------------------")
print(f"Data Retrieval Complete")     
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 0 | pacific grove
# Processing Record 1 of Set 0 | hermanus
# Processing Record 2 of Set 0 | hobyo
# Processing Record 3 of Set 0 | pitimbu
# Processing Record 4 of Set 0 | hobart
# Processing Record 5 of Set 0 | upernavik
# Processing Record 6 of Set 0 | bluff
# Processing Record 7 of Set 0 | nizhneyansk
# City not found. Skipping..
# Processing Record 8 of Set 0 | hilo
# Processing Record 9 of Set 0 | ituni
# City not found. Skipping..
# Processing Record 10 of Set 0 | sentyabrskiy
# City not found. Skipping..
# Processing Record 11 of Set 0 | bubaque
# Processing Record 12 of Set 0 | ushuaia
# Processing Record 13 of Set 0 | kapaa
# Processing Record 14 of Set 0 | albany
# Processing Record 15 of Set 0 | strezhevoy
# Processing Record 16 of Set 0 | dolbeau
# City not found. Skipping..
# Processing Record 17 of Set 0 | hasaki
# Processing Record 18 of Set 0 | saint george
# Processing Record 19 of Set 0 | vao
# Processing Record 20 of Set 0 | bac lieu
# Processing Record 21 of Set 0 | toliary
# City not found. Skipping..
# Processing Record 22 of Set 0 | port blair
# Processing Record 23 of Set 0 | vaini
# Processing Record 24 of Set 0 | rikitea
# Processing Record 25 of Set 0 | palabuhanratu
# City not found. Skipping..
# Processing Record 26 of Set 0 | mataura
# Processing Record 27 of Set 0 | busselton
# Processing Record 28 of Set 0 | los llanos de aridane
# Processing Record 29 of Set 0 | hofn
# Processing Record 30 of Set 0 | faanui
# Processing Record 31 of Set 0 | tsihombe
# City not found. Skipping..
# Processing Record 32 of Set 0 | farmington
# Processing Record 33 of Set 0 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 0 | chuy
# Processing Record 35 of Set 0 | new norfolk
# Processing Record 36 of Set 0 | airai
# Processing Record 37 of Set 0 | port hedland
# Processing Record 38 of Set 0 | barentsburg
# City not found. Skipping..
# Processing Record 39 of Set 0 | raesfeld
# Processing Record 40 of Set 0 | hope
# Processing Record 41 of Set 0 | the pas
# Processing Record 42 of Set 0 | seoul
# Processing Record 43 of Set 0 | hami
# Processing Record 44 of Set 0 | campbell river
# Processing Record 45 of Set 0 | arraial do cabo
# Processing Record 46 of Set 0 | illoqqortoormiut
# City not found. Skipping..
# Processing Record 47 of Set 0 | parnamirim
# Processing Record 48 of Set 0 | kashiwazaki
# Processing Record 49 of Set 0 | ouadda
# Processing Record 0 of Set 1 | fukuma
# Processing Record 1 of Set 1 | lasa
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | wewak
# Processing Record 4 of Set 1 | krupina
# Processing Record 5 of Set 1 | tocopilla
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | hare bay
# Processing Record 9 of Set 1 | puerto suarez
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | praia
# Processing Record 15 of Set 1 | tyler
# Processing Record 16 of Set 1 | aswan
# Processing Record 17 of Set 1 | porangatu
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | tura
# Processing Record 21 of Set 1 | severodvinsk
# Processing Record 22 of Set 1 | olafsvik
# Processing Record 23 of Set 1 | princeton
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | daru
# Processing Record 26 of Set 1 | beira
# Processing Record 27 of Set 1 | leningradskiy
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | imbituba
# Processing Record 30 of Set 1 | banda aceh
# Processing Record 31 of Set 1 | acapulco
# Processing Record 32 of Set 1 | imeni poliny osipenko
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping..
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | yenagoa
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | lagoa
# Processing Record 38 of Set 1 | meybod
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | jamame
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | satitoa
# City not found. Skipping..
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | okhotsk
# Processing Record 45 of Set 1 | turayf
# Processing Record 46 of Set 1 | paragominas
# Processing Record 47 of Set 1 | ketchikan
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 0 of Set 2 | saldanha
# Processing Record 1 of Set 2 | sitka
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | zamora
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | karratha
# Processing Record 7 of Set 2 | biak
# Processing Record 8 of Set 2 | guaratuba
# Processing Record 9 of Set 2 | jeremoabo
# Processing Record 10 of Set 2 | puerto colombia
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping..
# Processing Record 12 of Set 2 | muyezerskiy
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | bowen
# Processing Record 15 of Set 2 | vardo
# Processing Record 16 of Set 2 | ostersund
# Processing Record 17 of Set 2 | hailey
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | manoel urbano
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | kayan
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | skjervoy
# Processing Record 27 of Set 2 | port lincoln
# Processing Record 28 of Set 2 | husavik
# Processing Record 29 of Set 2 | haines junction
# Processing Record 30 of Set 2 | gamba
# Processing Record 31 of Set 2 | henderson
# Processing Record 32 of Set 2 | bogotol
# Processing Record 33 of Set 2 | xihua
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping..
# Processing Record 35 of Set 2 | honiara
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | gilazi
# City not found. Skipping..
# Processing Record 38 of Set 2 | plettenberg bay
# Processing Record 39 of Set 2 | riohacha
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | shimoda
# Processing Record 43 of Set 2 | lagunas
# Processing Record 44 of Set 2 | kishtwar
# Processing Record 45 of Set 2 | yokadouma
# Processing Record 46 of Set 2 | kahului
# Processing Record 47 of Set 2 | cheyenne
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | tulagi
# Processing Record 0 of Set 3 | aktau
# Processing Record 1 of Set 3 | sao felix do xingu
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | grand gaube
# Processing Record 4 of Set 3 | atambua
# Processing Record 5 of Set 3 | luderitz
# Processing Record 6 of Set 3 | shingu
# Processing Record 7 of Set 3 | sao sebastiao
# Processing Record 8 of Set 3 | codrington
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | kamina
# Processing Record 12 of Set 3 | tateyama
# Processing Record 13 of Set 3 | limbang
# Processing Record 14 of Set 3 | itarema
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 38 of Set 4 | myski
# Processing Record 39 of Set 4 | college
# Processing Record 40 of Set 4 | sinnamary
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | honningsvag
# Processing Record 44 of Set 4 | tuatapere
# Processing Record 45 of Set 4 | iralaya
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | tabiauea
# City not found. Skipping..
# Processing Record 48 of Set 4 | nioro
# Processing Record 49 of Set 4 | khonuu
# City not found. Skipping..
# Processing Record 0 of Set 5 | tottori
# Processing Record 1 of Set 5 | belushya guba
# City not found. Skipping..
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | poum
# Processing Record 4 of Set 5 | qarqin
# Processing Record 5 of Set 5 | adre
# Processing Record 6 of Set 5 | palmas de monte alto
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | nizhniy tsasuchey
# Processing Record 9 of Set 5 | havre-saint-pierre
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | humaita
# Processing Record 12 of Set 5 | tlaxiaco
# City not found. Skipping..
# Processing Record 13 of Set 5 | cheuskiny
# City not found. Skipping..
# Processing Record 14 of Set 5 | lolua
# City not found. Skipping..
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | sambava
# Processing Record 17 of Set 5 | shoranur
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | zhangjiakou
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | hun
# Processing Record 22 of Set 5 | novobirilyussy
# Processing Record 23 of Set 5 | nazareno
# Processing Record 24 of Set 5 | cazaje
# City not found. Skipping..
# Processing Record 25 of Set 5 | port hardy
# Processing Record 26 of Set 5 | makakilo city
# Processing Record 27 of Set 5 | morgan city
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | kayerkan
# Processing Record 30 of Set 5 | poya
# Processing Record 31 of Set 5 | mehamn
# Processing Record 32 of Set 5 | coihaique
# Processing Record 33 of Set 5 | adrar
# Processing Record 34 of Set 5 | sao filipe
# Processing Record 35 of Set 5 | kokopo
# Processing Record 36 of Set 5 | ust-ilimsk
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | saveh
# Processing Record 39 of Set 5 | puerto plata
# Processing Record 40 of Set 5 | chumikan
# Processing Record 41 of Set 5 | beziers
# Processing Record 42 of Set 5 | san cristobal
# Processing Record 43 of Set 5 | kattivakkam
# Processing Record 44 of Set 5 | bria
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | tay ninh
# Processing Record 47 of Set 5 | bambous virieux
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping..
# Processing Record 49 of Set 5 | san borja
# Processing Record 0 of Set 6 | riviere-du-loup
# Processing Record 1 of Set 6 | kieta
# Processing Record 2 of Set 6 | taltal
# Processing Record 3 of Set 6 | knysna
# Processing Record 4 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping..
# Processing Record 5 of Set 6 | dzilam gonzalez
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | ampanihy
# Processing Record 8 of Set 6 | poplar bluff
# Processing Record 9 of Set 6 | mangai
# Processing Record 10 of Set 6 | bogale
# Processing Record 11 of Set 6 | berlevag
# Processing Record 12 of Set 6 | westport
# Processing Record 13 of Set 6 | kamaishi
# Processing Record 14 of Set 6 | kavieng
# Processing Record 15 of Set 6 | belyy yar
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | bud
# Processing Record 18 of Set 6 | samusu
# City not found. Skipping..
# Processing Record 19 of Set 6 | darhan
# Processing Record 20 of Set 6 | isangel
# Processing Record 21 of Set 6 | kapit
# Processing Record 22 of Set 6 | manavgat
# Processing Record 23 of Set 6 | saint paul
# Processing Record 24 of Set 6 | peniche
# Processing Record 25 of Set 6 | ternate
# Processing Record 26 of Set 6 | west chicago
# Processing Record 27 of Set 6 | maghama
# City not found. Skipping..
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | whitehorse
# Processing Record 30 of Set 6 | sabang
# Processing Record 31 of Set 6 | beringovskiy
# Processing Record 32 of Set 6 | kushima
# Processing Record 33 of Set 6 | vestmanna
# Processing Record 34 of Set 6 | dubbo
# Processing Record 35 of Set 6 | zhigalovo
# Processing Record 36 of Set 6 | aksu
# Processing Record 37 of Set 6 | yulara
# Processing Record 38 of Set 6 | mao
# Processing Record 39 of Set 6 | phayakkhaphum phisai
# Processing Record 40 of Set 6 | loralai
# Processing Record 41 of Set 6 | juneau
# Processing Record 42 of Set 6 | namatanai
# Processing Record 43 of Set 6 | rodrigues alves
# Processing Record 44 of Set 6 | kochubey
# Processing Record 45 of Set 6 | diamantino
# Processing Record 46 of Set 6 | barbar
# City not found. Skipping..
# Processing Record 47 of Set 6 | maha sarakham
# Processing Record 48 of Set 6 | taburi
# City not found. Skipping..
# Processing Record 49 of Set 6 | inuvik
# Processing Record 0 of Set 7 | fortuna
# Processing Record 1 of Set 7 | moryakovskiy zaton
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | masuda
# Processing Record 4 of Set 7 | regina
# Processing Record 5 of Set 7 | beloha
# Processing Record 6 of Set 7 | derzhavinsk
# Processing Record 7 of Set 7 | hay river
# Processing Record 8 of Set 7 | berwick
# Processing Record 9 of Set 7 | grindavik
# Processing Record 10 of Set 7 | lemesos
# City not found. Skipping..
# Processing Record 11 of Set 7 | viedma
# Processing Record 12 of Set 7 | aykhal
# Processing Record 13 of Set 7 | egvekinot
# Processing Record 14 of Set 7 | elmadag
# Processing Record 15 of Set 7 | shihezi
# Processing Record 16 of Set 7 | dudinka
# Processing Record 17 of Set 7 | plouzane
# Processing Record 18 of Set 7 | clyde river
# Processing Record 19 of Set 7 | kijang
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | portland
# Processing Record 22 of Set 7 | nha trang
# Processing Record 23 of Set 7 | paita
# Processing Record 24 of Set 7 | kasongo-lunda
# Processing Record 25 of Set 7 | wenchi
# Processing Record 26 of Set 7 | watsa
# Processing Record 49 of Set 8 | pilar
# Processing Record 0 of Set 9 | subacius
# City not found. Skipping..
# Processing Record 1 of Set 9 | moron
# Processing Record 2 of Set 9 | iqaluit
# Processing Record 3 of Set 9 | salta
# Processing Record 4 of Set 9 | oranjemund
# Processing Record 5 of Set 9 | ilo
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | umzimvubu
# City not found. Skipping..
# Processing Record 8 of Set 9 | naranjos
# Processing Record 9 of Set 9 | buala
# Processing Record 10 of Set 9 | vanimo
# Processing Record 11 of Set 9 | tres lagoas
# Processing Record 12 of Set 9 | namibe
# Processing Record 13 of Set 9 | nuuk
# Processing Record 14 of Set 9 | grand centre
# City not found. Skipping..
# Processing Record 15 of Set 9 | grevena
# Processing Record 16 of Set 9 | arequipa
# Processing Record 17 of Set 9 | victoria
# Processing Record 18 of Set 9 | kulhudhuffushi
# Processing Record 19 of Set 9 | batticaloa
# Processing Record 20 of Set 9 | katherine
# Processing Record 21 of Set 9 | pochutla
# Processing Record 22 of Set 9 | zhangye
# Processing Record 23 of Set 9 | goundam
# Processing Record 24 of Set 9 | kidal
# Processing Record 25 of Set 9 | severnoye
# Processing Record 26 of Set 9 | bafq
# Processing Record 27 of Set 9 | redditch
# Processing Record 28 of Set 9 | matagami
# Processing Record 29 of Set 9 | yongan
# Processing Record 30 of Set 9 | sinjah
# City not found. Skipping..
# Processing Record 31 of Set 9 | nantucket
# Processing Record 32 of Set 9 | nabire
# Processing Record 33 of Set 9 | bridlington
# Processing Record 34 of Set 9 | gazojak
# Processing Record 35 of Set 9 | mayumba
# Processing Record 36 of Set 9 | anadyr
# Processing Record 37 of Set 9 | leiyang
# Processing Record 38 of Set 9 | gewane
# Processing Record 39 of Set 9 | shelburne
# Processing Record 40 of Set 9 | pandan
# Processing Record 41 of Set 9 | erenhot
# Processing Record 42 of Set 9 | baruun-urt
# Processing Record 43 of Set 9 | opuwo
# Processing Record 44 of Set 9 | lucea
# Processing Record 45 of Set 9 | puerto leguizamo
# Processing Record 46 of Set 9 | jimma
# Processing Record 47 of Set 9 | juba
# Processing Record 48 of Set 9 | sedalia
# Processing Record 49 of Set 9 | maceio
# Processing Record 0 of Set 10 | finschhafen
# Processing Record 1 of Set 10 | henties bay
# Processing Record 2 of Set 10 | taoudenni
# Processing Record 3 of Set 10 | chilca
# Processing Record 4 of Set 10 | nizhniy kuranakh
# Processing Record 5 of Set 10 | tahta
# Processing Record 6 of Set 10 | broome
# Processing Record 7 of Set 10 | shouguang
# Processing Record 8 of Set 10 | cuiluan
# Processing Record 9 of Set 10 | payo
# Processing Record 10 of Set 10 | rantauprapat
# Processing Record 11 of Set 10 | tumannyy
# City not found. Skipping..
# Processing Record 12 of Set 10 | sume
# Processing Record 13 of Set 10 | nouakchott
# Processing Record 14 of Set 10 | vagamo
# Processing Record 15 of Set 10 | bolungarvik
# City not found. Skipping..
# Processing Record 16 of Set 10 | trelew
# Processing Record 17 of Set 10 | coari
# Processing Record 18 of Set 10 | masunga
# Processing Record 19 of Set 10 | listvyanskiy
# Processing Record 20 of Set 10 | colinas
# Processing Record 21 of Set 10 | bembereke
# Processing Record 22 of Set 10 | bay roberts
# Processing Record 23 of Set 10 | waipawa
# Processing Record 24 of Set 10 | kabale
# Processing Record 25 of Set 10 | tiznit
# Processing Record 26 of Set 10 | yugorsk
# Processing Record 27 of Set 10 | ustye
# Processing Record 28 of Set 10 | muncar
# Processing Record 29 of Set 10 | brandon
# Processing Record 30 of Set 10 | te anau
# Processing Record 31 of Set 10 | boma
# Processing Record 32 of Set 10 | dalneye konstantinovo
# City not found. Skipping..
# Processing Record 33 of Set 10 | goderich
# Processing Record 34 of Set 10 | diego de almagro
# Processing Record 35 of Set 10 | sakakah
# Processing Record 36 of Set 10 | kon tum
# Processing Record 37 of Set 10 | chara
# Processing Record 38 of Set 10 | vallenar
# Processing Record 39 of Set 10 | borogontsy
# Processing Record 40 of Set 10 | vila franca do campo
# Processing Record 41 of Set 10 | yangjiang
# Processing Record 42 of Set 10 | ponta delgada
# Processing Record 43 of Set 10 | acajutla
# Processing Record 44 of Set 10 | warrnambool
# Processing Record 45 of Set 10 | mezen
# Processing Record 46 of Set 10 | fare
# Processing Record 47 of Set 10 | kaspiyskiy
# Processing Record 48 of Set 10 | gorom-gorom
# Processing Record 49 of Set 10 | pagman
# City not found. Skipping..
# Processing Record 0 of Set 11 | russell
# Processing Record 1 of Set 11 | sur
# Processing Record 2 of Set 11 | ossora
# Processing Record 3 of Set 11 | evensk
# Processing Record 4 of Set 11 | ikole
# City not found. Skipping..
# Processing Record 5 of Set 11 | verkhnyaya sysert
# Processing Record 6 of Set 11 | marovoay
# Processing Record 7 of Set 11 | newport
# Processing Record 8 of Set 11 | seabra
# Processing Record 9 of Set 11 | abonnema
# Processing Record 10 of Set 11 | icod de los vinos
# Processing Record 11 of Set 11 | necochea
# Processing Record 12 of Set 11 | smithers
# Processing Record 13 of Set 11 | sechura
# Processing Record 14 of Set 11 | ruteng
# Processing Record 15 of Set 11 | zheleznodorozhnyy
# Processing Record 16 of Set 11 | maniitsoq
# Processing Record 17 of Set 11 | moiyabana
# City not found. Skipping..
# Processing Record 18 of Set 11 | alice springs
# Processing Record 19 of Set 11 | coxim
# Processing Record 20 of Set 11 | mrirt
# City not found. Skipping..
# Processing Record 21 of Set 11 | tazovskiy
# Processing Record 22 of Set 11 | springfield
# Processing Record 23 of Set 11 | yerbogachen
# Processing Record 24 of Set 11 | santa maria
# Processing Record 25 of Set 11 | tabory
# Processing Record 26 of Set 11 | uwayl
# City not found. Skipping..
# Processing Record 27 of Set 11 | saleaula
# City not found. Skipping..
# Processing Record 28 of Set 11 | linhares
# Processing Record 29 of Set 11 | tilichiki
# Processing Record 30 of Set 11 | laguna
# Processing Record 31 of Set 11 | umm bab
# Processing Record 32 of Set 11 | parainen
# Processing Record 33 of Set 11 | estremoz
# Processing Record 34 of Set 11 | talnakh
# Processing Record 35 of Set 11 | fernley
# Processing Record 36 of Set 11 | vestmannaeyjar
# Processing Record 37 of Set 11 | margate
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | filingue
# Processing Record 40 of Set 11 | souillac
# Processing Record 41 of Set 11 | oistins
# Processing Record 42 of Set 11 | calabozo
# Processing Record 43 of Set 11 | xiuyan
# Processing Record 44 of Set 11 | vredendal
# Processing Record 45 of Set 11 | alyangula
# Processing Record 46 of Set 11 | williams lake
# Processing Record 47 of Set 11 | pozo colorado
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | vuktyl
# Processing Record 0 of Set 12 | los algarrobos
# Processing Record 1 of Set 12 | louisbourg
# City not found. Skipping..
# Processing Record 2 of Set 12 | great yarmouth
# Processing Record 3 of Set 12 | barawe
# City not found. Skipping..
# Processing Record 4 of Set 12 | kloulklubed
# Processing Record 5 of Set 12 | tabou
# Processing Record 6 of Set 12 | sao gabriel da cachoeira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
units = "Imperial"
base_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}"

city = "paita"
city_url = f"{base_url}&q={city}"
response = requests.get(city_url).json()
response
# Out:
# {'coord': {'lon': -81.11, 'lat': -5.09},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 62.28,
#   'feels_like': 57.29,
#   'temp_min': 62.28,
#   'temp_max': 62.28,
#   'pressure': 1011,
#   'humidity': 86,
#   'sea_level': 1011,
#   'grnd_level': 1003},
#  'visibility': 10000,
#  'wind': {'speed': 13.4, 'deg': 214},
#  'clouds': {'all': 5},
#  'dt': 1596238222,
#  'sys': {'country': 'PE', 'sunrise': 1596195233, 'sunset': 1596238053},
#  'timezone': -18000,
#  'id': 3694112,
#  'name': 'Paita',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
sum = {"City": weather_city, "Lat": lat, "Lng": lng, 
       "Max Temp": max_temp, "Humidity": humidity, 
       "Cloudiness": cloudiness, "Wind Speed": wind_speed, 
       "Country": country, "Date": date}

weather_df = pd.DataFrame(sum)
weather_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
weather_df
# Out:
#                          City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0               pacific grove  36.62 -121.92     71.01        60           1
# 1                    hermanus -34.42   19.23     44.01        95           1
# 2                       hobyo   5.35   48.53     77.16        75           1
# 3                     pitimbu  -7.47  -34.81     73.40        94          20
# 4                      hobart -42.88  147.33     50.00        71          75
# ..                        ...    ...     ...       ...       ...         ...
# 552            los algarrobos   8.50  -82.43     86.00        74          40
# 553            great yarmouth  52.61    1.73     73.00        82          58
# 554               kloulklubed   7.04  134.26     78.80        94          90
# 555                     tabou   4.42   -7.35     75.15        86          92
# 556  sao gabriel da cachoeira  -0.13  -67.09     77.09        64          10
#
#      Wind Speed Country        Date
# 0          9.17      US  1596238050
# 1          5.75      ZA  1596238148
# 2         28.16      SO  1596238149
# 3          5.82      BR  1596238149
# 4         10.29      AU  1596237898
# ..          ...     ...         ...
# 552        6.93      PA  1596238270
# 553        1.01      GB  1596238270
# 554        5.82      PW  1596238270
# 555       11.92      CI  1596238271
# 556        0.78      BR  1596238271
#
# [557 rows x 9 columns]

# %%
#Export DataFrame to CSV File
weather_df.to_csv("../output_data/weather_df.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df = weather_df[weather_df["Humidity"] <= 100]
weather_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pacific grove  36.62 -121.92     71.01        60           1        9.17
# 1       hermanus -34.42   19.23     44.01        95           1        5.75
# 2          hobyo   5.35   48.53     77.16        75           1       28.16
# 3        pitimbu  -7.47  -34.81     73.40        94          20        5.82
# 4         hobart -42.88  147.33     50.00        71          75       10.29
#
#   Country        Date
# 0      US  1596238050
# 1      ZA  1596238148
# 2      SO  1596238149
# 3      BR  1596238149
# 4      AU  1596237898

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean    19.978061   14.898600   69.957253   70.129264   48.131059    7.854381
# std     33.110105   91.894027   13.374569   21.371866   37.528585    5.507134
# min    -54.800000 -179.170000   33.800000    1.000000    0.000000    0.450000
# 25%     -7.740000  -66.850000   59.790000   58.000000    9.000000    3.940000
# 50%     21.460000   18.420000   72.000000   75.000000   43.000000    6.600000
# 75%     48.420000   99.830000   79.070000   87.000000   87.000000   10.290000
# max     78.220000  179.320000  111.200000  100.000000  100.000000   30.650000
#
#                Date
# count  5.570000e+02
# mean   1.596238e+09
# std    6.790144e+01
# min    1.596238e+09
# 25%    1.596238e+09
# 50%    1.596238e+09
# 75%    1.596238e+09
# max    1.596238e+09

# %%
#  Get the indices of cities that have humidity over 100%.
indexes = weather_df[weather_df["Humidity"]>100]["City"].index
indexes
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_data = weather_df.drop(indexes, inplace=False)
clean_data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pacific grove  36.62 -121.92     71.01        60           1        9.17
# 1       hermanus -34.42   19.23     44.01        95           1        5.75
# 2          hobyo   5.35   48.53     77.16        75           1       28.16
# 3        pitimbu  -7.47  -34.81     73.40        94          20        5.82
# 4         hobart -42.88  147.33     50.00        71          75       10.29
#
#   Country        Date
# 0      US  1596238050
# 1      ZA  1596238148
# 2      SO  1596238149
# 3      BR  1596238149
# 4      AU  1596237898

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
clean_data.to_csv('../output_data/clean_city.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
temp= clean_data["Max Temp"]
lat= clean_data["Lat"]

plt.figure(1)
fig = plt.figure(figsize=(5,5))

plt.scatter(lat, temp, marker="o", facecolors="blue", edgecolors="black", alpha = 0.5 )
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature (F) ({today})")
plt.grid(True)

fig.savefig('../output_data/Fig1.png', bbox_inches='tight', dpi=150)
plt.show()
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="500">
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
humidity = clean_data["Humidity"]
lat= clean_data["Lat"]

plt.figure(2)

plt.scatter(lat, humidity , facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%)({today})")
fig.savefig('../output_data/Fig2.png', bbox_inches='tight', dpi=150)
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
cloudiness = clean_data["Cloudiness"]
lat= clean_data["Lat"]

plt.figure(3)
plt.scatter(lat, cloudiness, facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
fig.savefig('../output_data/fig3.png', bbox_inches='tight', dpi=150)

print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
plt.show()
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
wind_speed = clean_data["Wind Speed"]
lat= clean_data["Lat"]

plt.figure(4)
plt.scatter(lat, wind_speed, facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
fig.savefig('../output_data/fig4.png', bbox_inches='tight', dpi=150)

print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = clean_data.loc[clean_data["Lat"] > 0,:]
southern_df = clean_data.loc[clean_data["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(5)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"Northern Hemisphere - Max Temp vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: -0.6577847644532192
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(6)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.806587991210854
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(7)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: -0.02002711423020236
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(8)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: -0.10036399416462048
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(9)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: -0.00802987083718976
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(10)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.005889388835745391
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(11)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,13),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: -0.03815165568465475
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(12)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({today})")
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: -0.06796253473737017
# The regression does not display much of a correlation between the data sets.
